# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
geo = pd.read_csv('Geo_scores.csv')
instance = pd.read_csv('instance_scores.csv')
lambdawts = pd.read_csv('Lambda_wts.csv')
qsets = pd.read_csv('Qset_tats.csv')
test = pd.read_csv('test_share.csv')
train = pd.read_csv('train.csv')

# %%
print(geo.head(1))
print("********************"*5)
print(instance.head(1))
print("********************"*5)
print(lambdawts.head(1))
print("********************"*5)
print(qsets.head(1))
print("********************"*5)
print(test.head(1))
print("********************"*5)
print(train.head(1))
# Out:
#       id  geo_score
# 0  26674       4.48
# ****************************************************************************************************
#        id  instance_scores
# 0  173444            -0.88
# ****************************************************************************************************
#     Group  lambda_wt
# 0  Grp936       3.41
# ****************************************************************************************************
#      id  qsets_normalized_tat
# 0  9983                  2.41
# ****************************************************************************************************
#        id   Group  Per1  Per2  Per3  Per4  Per5  Per6  Per7      Per8  ...  \
# 0  146574  Grp229  -0.3  1.54  0.22 -0.28  0.57  0.26   0.7  1.076667  ...
#
#        Dem7      Dem8      Dem9     Cred1     Cred2     Cred3     Cred4  \
# 0  0.786667  0.546667  0.313333  0.703333  0.813333  0.776667  0.796667
#
#       Cred5     Cred6  Normalised_FNT
# 0  0.823333  0.783333         -249.75
#
# [1 rows x 27 columns]
# ****************************************************************************************************
#        id   Group  Per1  Per2  Per3      Per4      Per5      Per6  Per7  Per8  \
# 0  112751  Grp169  1.07  0.58  0.48  0.766667  1.233333  1.993333  0.34  1.01
#
#    ...  Dem8      Dem9     Cred1  Cred2     Cred3     Cred4     Cred5  \
# 0  ...  0.68  0.726667  0.606667   1.01  0.933333  0.603333  0.686667
#
#       Cred6  Normalised_FNT  Target
# 0  0.673333         -245.75       0
#
# [1 rows x 28 columns]

# %%
print(geo.shape)
print("********************"*5)
print(instance.shape)
print("********************"*5)
print(lambdawts.shape)
print("********************"*5)
print(qsets.shape)
print("********************"*5)
print(test.shape)
print("********************"*5)
print(train.shape)
# Out:
# (1424035, 2)
# ****************************************************************************************************
# (1424035, 2)
# ****************************************************************************************************
# (1400, 2)
# ****************************************************************************************************
# (1424035, 2)
# ****************************************************************************************************
# (56962, 27)
# ****************************************************************************************************
# (227845, 28)

# %%
geo['id'].value_counts().head()
# Out:
# 26674     5
# 149679    5
# 114110    5
# 24969     5
# 262179    5
# Name: id, dtype: int64

# %%
geo['id'].nunique()
# Out:
# 284807

# %%
geo.isnull().sum()/len(geo)*100
# Out:
# id           0.000000
# geo_score    5.023964
# dtype: float64

# %%
geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1424035 entries, 0 to 1424034
# Data columns (total 2 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   id         1424035 non-null  int64
#  1   geo_score  1352492 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 21.7 MB

# %%
sns.boxplot(y='geo_score', data=geo)
# Out:
# <AxesSubplot:ylabel='geo_score'>

# %%
geo.describe()
# Out:
#                  id     geo_score
# count  1.424035e+06  1.352492e+06
# mean   1.424030e+05 -9.279168e-06
# std    8.221673e+04  7.827199e+00
# min    0.000000e+00 -1.093900e+02
# 25%    7.120100e+04 -5.860000e+00
# 50%    1.424030e+05  1.800000e-01
# 75%    2.136050e+05  5.860000e+00
# max    2.848060e+05  4.581000e+01

# %%
geo.fillna(0, inplace=True)

# %%
geo.isnull().sum()
# Out:
# id           0
# geo_score    0
# dtype: int64

# %%
instance['id'].value_counts().head()
# Out:
# 173444    5
# 240342    5
# 147158    5
# 83677     5
# 127535    5
# Name: id, dtype: int64

# %%
instance['id'].nunique()
# Out:
# 284807

# %%
instance.isnull().sum()
# Out:
# id                 0
# instance_scores    0
# dtype: int64

# %%
lambdawts.isnull().sum()
# Out:
# Group        0
# lambda_wt    0
# dtype: int64

# %%
qsets['id'].nunique()
# Out:
# 284807

# %%
qsets.isnull().sum()/len(qsets)*100
# Out:
# id                      0.000000
# qsets_normalized_tat    7.247083
# dtype: float64

# %%
sns.boxplot(y='qsets_normalized_tat', data=qsets)
# Out:
# <AxesSubplot:ylabel='qsets_normalized_tat'>

# %%
qsets.describe()
# Out:
#                  id  qsets_normalized_tat
# count  1.424035e+06          1.320834e+06
# mean   1.424030e+05          1.094006e-05
# std    8.221673e+04          7.731794e+00
# min    0.000000e+00         -1.404400e+02
# 25%    7.120100e+04         -5.860000e+00
# 50%    1.424030e+05          2.000000e-02
# 75%    2.136050e+05          5.860000e+00
# max    2.848060e+05          6.110000e+01

# %%
qsets.fillna(0, inplace=True)

# %%
qsets.isnull().sum()
# Out:
# id                      0
# qsets_normalized_tat    0
# dtype: int64

# %%
test['id'].nunique()
# Out:
# 56962

# %%
test.isnull().sum()
# Out:
# id                0
# Group             0
# Per1              0
# Per2              0
# Per3              0
# Per4              0
# Per5              0
# Per6              0
# Per7              0
# Per8              0
# Per9              0
# Dem1              0
# Dem2              0
# Dem3              0
# Dem4              0
# Dem5              0
# Dem6              0
# Dem7              0
# Dem8              0
# Dem9              0
# Cred1             0
# Cred2             0
# Cred3             0
# Cred4             0
# Cred5             0
# Cred6             0
# Normalised_FNT    0
# dtype: int64

# %%
train['id'].nunique()
# Out:
# 227845

# %%
227845+56962
# Out:
# 284807

# %%
train.isnull().sum()
# Out:
# id                0
# Group             0
# Per1              0
# Per2              0
# Per3              0
# Per4              0
# Per5              0
# Per6              0
# Per7              0
# Per8              0
# Per9              0
# Dem1              0
# Dem2              0
# Dem3              0
# Dem4              0
# Dem5              0
# Dem6              0
# Dem7              0
# Dem8              0
# Dem9              0
# Cred1             0
# Cred2             0
# Cred3             0
# Cred4             0
# Cred5             0
# Cred6             0
# Normalised_FNT    0
# Target            0
# dtype: int64

# %%
# Make groupby id basis mean/sum 

geo = geo.groupby('id').mean()

# %%
geo.shape
# Out:
# (284807, 1)

# %%
instance = instance.groupby('id').mean()

# %%
instance.shape
# Out:
# (284807, 1)

# %%
instance.head()
# Out:
#     instance_scores
# id
# 0              0.09
# 1             -0.17
# 2              0.21
# 3             -0.05
# 4              0.75

# %%
qsets = qsets.groupby('id').mean()

# %%
qsets.shape
# Out:
# (284807, 1)

# %%
lambdawts.head()
# Out:
#      Group  lambda_wt
# 0   Grp936       3.41
# 1   Grp347      -2.88
# 2   Grp188       0.39
# 3  Grp1053      -2.75
# 4    Grp56      -0.83

# %%
lambdawts.shape
# Out:
# (1400, 2)

# %%
lambdawts['Group'].nunique()
# Out:
# 1400

# %%
train['Group'].nunique()
# Out:
# 1301

# %%
test['Group'].nunique()
# Out:
# 915

# %%
1301+915
# Out:
# 2216

# %%
train['data'] = 'train'
test['data'] = 'test'

# %%
train.head()
# Out:
#        id   Group      Per1      Per2      Per3      Per4      Per5      Per6  \
# 0  112751  Grp169  1.070000  0.580000  0.480000  0.766667  1.233333  1.993333
# 1   18495  Grp161  0.473333  1.206667  0.883333  1.430000  0.726667  0.626667
# 2   23915  Grp261  1.130000  0.143333  0.946667  0.123333  0.080000  0.836667
# 3   50806  Grp198  0.636667  1.090000  0.750000  0.940000  0.743333  0.346667
# 4  184244  Grp228  0.560000  1.013333  0.593333  0.416667  0.773333  0.460000
#
#        Per7      Per8  ...      Dem9     Cred1     Cred2     Cred3     Cred4  \
# 0  0.340000  1.010000  ...  0.726667  0.606667  1.010000  0.933333  0.603333
# 1  0.810000  0.783333  ...  0.743333  0.680000  0.690000  0.560000  0.670000
# 2  0.056667  0.756667  ...  0.820000  0.600000  0.383333  0.763333  0.670000
# 3  0.956667  0.633333  ...  0.900000  0.680000  0.846667  0.423333  0.520000
# 4  0.853333  0.796667  ...  0.486667  0.693333  0.526667  0.520000  0.716667
#
#       Cred5     Cred6  Normalised_FNT  Target   data
# 0  0.686667  0.673333       -245.7500       0  train
# 1  0.553333  0.653333       -248.0000       0  train
# 2  0.686667  0.673333       -233.1250       0  train
# 3  0.846667  0.760000       -249.7775       0  train
# 4  0.706667  0.673333       -247.5775       0  train
#
# [5 rows x 29 columns]

# %%
test.head()
# Out:
#        id   Group      Per1      Per2      Per3      Per4      Per5      Per6  \
# 0  146574  Grp229 -0.300000  1.540000  0.220000 -0.280000  0.570000  0.260000
# 1  268759  Grp141  0.633333  0.953333  0.810000  0.466667  0.910000  0.253333
# 2   59727  Grp188  1.043333  0.740000  0.860000  1.006667  0.583333  0.616667
# 3  151544  Grp426  1.283333  0.300000  0.576667  0.636667  0.256667  0.543333
# 4  155008  Grp443  1.186667  0.326667  0.476667  0.866667  0.436667  0.680000
#
#        Per7      Per8  ...      Dem8      Dem9     Cred1     Cred2     Cred3  \
# 0  0.700000  1.076667  ...  0.546667  0.313333  0.703333  0.813333  0.776667
# 1  1.040000  0.550000  ...  0.770000  0.993333  0.536667  0.703333  0.806667
# 2  0.630000  0.686667  ...  0.756667  0.953333  0.623333  0.753333  0.870000
# 3  0.356667  0.663333  ...  0.460000  0.260000  0.800000  0.606667  0.456667
# 4  0.476667  0.686667  ...  0.740000  0.823333  0.670000  0.896667  0.566667
#
#       Cred4     Cred5     Cred6  Normalised_FNT  data
# 0  0.796667  0.823333  0.783333       -249.7500  test
# 1  0.630000  0.673333  0.673333       -249.8125  test
# 2  0.596667  0.680000  0.670000       -248.1200  test
# 3  0.320000  0.676667  0.660000       -222.9875  test
# 4  0.546667  0.650000  0.663333       -196.2200  test
#
# [5 rows x 28 columns]

# %%
all_data = pd.concat([train, test], axis=0)

# %%
all_data.head()
# Out:
#        id   Group      Per1      Per2      Per3      Per4      Per5      Per6  \
# 0  112751  Grp169  1.070000  0.580000  0.480000  0.766667  1.233333  1.993333
# 1   18495  Grp161  0.473333  1.206667  0.883333  1.430000  0.726667  0.626667
# 2   23915  Grp261  1.130000  0.143333  0.946667  0.123333  0.080000  0.836667
# 3   50806  Grp198  0.636667  1.090000  0.750000  0.940000  0.743333  0.346667
# 4  184244  Grp228  0.560000  1.013333  0.593333  0.416667  0.773333  0.460000
#
#        Per7      Per8  ...      Dem9     Cred1     Cred2     Cred3     Cred4  \
# 0  0.340000  1.010000  ...  0.726667  0.606667  1.010000  0.933333  0.603333
# 1  0.810000  0.783333  ...  0.743333  0.680000  0.690000  0.560000  0.670000
# 2  0.056667  0.756667  ...  0.820000  0.600000  0.383333  0.763333  0.670000
# 3  0.956667  0.633333  ...  0.900000  0.680000  0.846667  0.423333  0.520000
# 4  0.853333  0.796667  ...  0.486667  0.693333  0.526667  0.520000  0.716667
#
#       Cred5     Cred6  Normalised_FNT  Target   data
# 0  0.686667  0.673333       -245.7500     0.0  train
# 1  0.553333  0.653333       -248.0000     0.0  train
# 2  0.686667  0.673333       -233.1250     0.0  train
# 3  0.846667  0.760000       -249.7775     0.0  train
# 4  0.706667  0.673333       -247.5775     0.0  train
#
# [5 rows x 29 columns]

# %%
all_data.tail()
# Out:
#            id   Group      Per1      Per2      Per3      Per4      Per5  \
# 56957   18333  Grp102  0.553333  1.043333  1.096667  0.686667  0.673333
# 56958  244207  Grp504  1.353333  0.616667  0.276667  0.783333  0.690000
# 56959  103277   Grp78  1.083333  0.433333  0.806667  0.490000  0.243333
# 56960  273294  Grp134  0.566667  1.153333  0.370000  0.616667  0.793333
# 56961  223337   Grp18  1.426667  0.110000 -0.006667 -0.200000  0.983333
#
#            Per6      Per7      Per8  ...      Dem9     Cred1     Cred2  \
# 56957  0.340000  0.900000  0.643333  ...  0.433333  0.660000  0.776667
# 56958  0.650000  0.473333  0.670000  ...  0.870000  0.683333  0.690000
# 56959  0.316667  0.533333  0.606667  ...  0.063333  0.753333  0.780000
# 56960  0.226667  0.910000  0.696667  ...  1.026667  0.626667  0.646667
# 56961  1.870000  0.033333  0.963333  ...  0.670000  0.770000  0.893333
#
#           Cred3     Cred4     Cred5     Cred6  Normalised_FNT  Target  data
# 56957  0.610000  0.690000  0.750000  0.700000       -249.5050     NaN  test
# 56958  0.640000  0.883333  0.663333  0.660000       -248.7525     NaN  test
# 56959  0.603333  0.880000  0.643333  0.676667       -231.0500     NaN  test
# 56960  0.566667  0.616667  0.713333  0.706667       -246.3150     NaN  test
# 56961  0.586667  0.616667  0.683333  0.650000       -248.4500     NaN  test
#
# [5 rows x 29 columns]

# %%
all_data.shape
# Out:
# (284807, 29)

# %%
all_data['Group'].nunique()
# Out:
# 1400

# %%
all_data = pd.merge(all_data, geo, on='id', how='left')

# %%
all_data.head()
# Out:
#        id   Group      Per1      Per2      Per3      Per4      Per5      Per6  \
# 0  112751  Grp169  1.070000  0.580000  0.480000  0.766667  1.233333  1.993333
# 1   18495  Grp161  0.473333  1.206667  0.883333  1.430000  0.726667  0.626667
# 2   23915  Grp261  1.130000  0.143333  0.946667  0.123333  0.080000  0.836667
# 3   50806  Grp198  0.636667  1.090000  0.750000  0.940000  0.743333  0.346667
# 4  184244  Grp228  0.560000  1.013333  0.593333  0.416667  0.773333  0.460000
#
#        Per7      Per8  ...     Cred1     Cred2     Cred3     Cred4     Cred5  \
# 0  0.340000  1.010000  ...  0.606667  1.010000  0.933333  0.603333  0.686667
# 1  0.810000  0.783333  ...  0.680000  0.690000  0.560000  0.670000  0.553333
# 2  0.056667  0.756667  ...  0.600000  0.383333  0.763333  0.670000  0.686667
# 3  0.956667  0.633333  ...  0.680000  0.846667  0.423333  0.520000  0.846667
# 4  0.853333  0.796667  ...  0.693333  0.526667  0.520000  0.716667  0.706667
#
#       Cred6  Normalised_FNT  Target   data  geo_score
# 0  0.673333       -245.7500     0.0  train       0.22
# 1  0.653333       -248.0000     0.0  train      -0.25
# 2  0.673333       -233.1250     0.0  train      -0.95
# 3  0.760000       -249.7775     0.0  train       0.49
# 4  0.673333       -247.5775     0.0  train       0.85
#
# [5 rows x 30 columns]

# %%
all_data = pd.merge(all_data, instance, on='id', how='left')

# %%
all_data.head()
# Out:
#        id   Group      Per1      Per2      Per3      Per4      Per5      Per6  \
# 0  112751  Grp169  1.070000  0.580000  0.480000  0.766667  1.233333  1.993333
# 1   18495  Grp161  0.473333  1.206667  0.883333  1.430000  0.726667  0.626667
# 2   23915  Grp261  1.130000  0.143333  0.946667  0.123333  0.080000  0.836667
# 3   50806  Grp198  0.636667  1.090000  0.750000  0.940000  0.743333  0.346667
# 4  184244  Grp228  0.560000  1.013333  0.593333  0.416667  0.773333  0.460000
#
#        Per7      Per8  ...     Cred2     Cred3     Cred4     Cred5     Cred6  \
# 0  0.340000  1.010000  ...  1.010000  0.933333  0.603333  0.686667  0.673333
# 1  0.810000  0.783333  ...  0.690000  0.560000  0.670000  0.553333  0.653333
# 2  0.056667  0.756667  ...  0.383333  0.763333  0.670000  0.686667  0.673333
# 3  0.956667  0.633333  ...  0.846667  0.423333  0.520000  0.846667  0.760000
# 4  0.853333  0.796667  ...  0.526667  0.520000  0.716667  0.706667  0.673333
#
#    Normalised_FNT  Target   data  geo_score  instance_scores
# 0       -245.7500     0.0  train       0.22            -0.06
# 1       -248.0000     0.0  train      -0.25             0.52
# 2       -233.1250     0.0  train      -0.95             1.56
# 3       -249.7775     0.0  train       0.49             0.70
# 4       -247.5775     0.0  train       0.85            -0.47
#
# [5 rows x 31 columns]

# %%
all_data = pd.merge(all_data, qsets, on='id', how='left')

# %%
all_data.head()
# Out:
#        id   Group      Per1      Per2      Per3      Per4      Per5      Per6  \
# 0  112751  Grp169  1.070000  0.580000  0.480000  0.766667  1.233333  1.993333
# 1   18495  Grp161  0.473333  1.206667  0.883333  1.430000  0.726667  0.626667
# 2   23915  Grp261  1.130000  0.143333  0.946667  0.123333  0.080000  0.836667
# 3   50806  Grp198  0.636667  1.090000  0.750000  0.940000  0.743333  0.346667
# 4  184244  Grp228  0.560000  1.013333  0.593333  0.416667  0.773333  0.460000
#
#        Per7      Per8  ...     Cred3     Cred4     Cred5     Cred6  \
# 0  0.340000  1.010000  ...  0.933333  0.603333  0.686667  0.673333
# 1  0.810000  0.783333  ...  0.560000  0.670000  0.553333  0.653333
# 2  0.056667  0.756667  ...  0.763333  0.670000  0.686667  0.673333
# 3  0.956667  0.633333  ...  0.423333  0.520000  0.846667  0.760000
# 4  0.853333  0.796667  ...  0.520000  0.716667  0.706667  0.673333
#
#    Normalised_FNT  Target   data  geo_score  instance_scores  \
# 0       -245.7500     0.0  train       0.22            -0.06
# 1       -248.0000     0.0  train      -0.25             0.52
# 2       -233.1250     0.0  train      -0.95             1.56
# 3       -249.7775     0.0  train       0.49             0.70
# 4       -247.5775     0.0  train       0.85            -0.47
#
#    qsets_normalized_tat
# 0                 -0.70
# 1                  0.14
# 2                 -0.43
# 3                 -0.31
# 4                 -0.63
#
# [5 rows x 32 columns]

# %%
all_data = pd.merge(all_data, lambdawts, on='Group', how='left')

# %%
lambdawts.head()
# Out:
#      Group  lambda_wt
# 0   Grp936       3.41
# 1   Grp347      -2.88
# 2   Grp188       0.39
# 3  Grp1053      -2.75
# 4    Grp56      -0.83

# %%
all_data.head()
# Out:
#        id   Group      Per1      Per2      Per3      Per4      Per5      Per6  \
# 0  112751  Grp169  1.070000  0.580000  0.480000  0.766667  1.233333  1.993333
# 1   18495  Grp161  0.473333  1.206667  0.883333  1.430000  0.726667  0.626667
# 2   23915  Grp261  1.130000  0.143333  0.946667  0.123333  0.080000  0.836667
# 3   50806  Grp198  0.636667  1.090000  0.750000  0.940000  0.743333  0.346667
# 4  184244  Grp228  0.560000  1.013333  0.593333  0.416667  0.773333  0.460000
#
#        Per7      Per8  ...     Cred4     Cred5     Cred6  Normalised_FNT  \
# 0  0.340000  1.010000  ...  0.603333  0.686667  0.673333       -245.7500
# 1  0.810000  0.783333  ...  0.670000  0.553333  0.653333       -248.0000
# 2  0.056667  0.756667  ...  0.670000  0.686667  0.673333       -233.1250
# 3  0.956667  0.633333  ...  0.520000  0.846667  0.760000       -249.7775
# 4  0.853333  0.796667  ...  0.716667  0.706667  0.673333       -247.5775
#
#    Target   data  geo_score  instance_scores  qsets_normalized_tat  lambda_wt
# 0     0.0  train       0.22            -0.06                 -0.70      -0.13
# 1     0.0  train      -0.25             0.52                  0.14       0.66
# 2     0.0  train      -0.95             1.56                 -0.43      -0.51
# 3     0.0  train       0.49             0.70                 -0.31       0.72
# 4     0.0  train       0.85            -0.47                 -0.63       0.60
#
# [5 rows x 33 columns]

# %%
all_data.shape
# Out:
# (284807, 33)

# %%
train = all_data[all_data['data']=='train']
test = all_data[all_data['data']=='test']

# %%
train.tail()
# Out:
#             id   Group      Per1      Per2      Per3      Per4      Per5  \
# 227840   97346  Grp232  0.476667  1.013333  0.536667  0.576667  1.406667
# 227841  147361  Grp199  1.363333  0.730000  0.060000  0.776667  0.883333
# 227842   50989   Grp36  1.060000  0.756667  0.906667  0.896667  0.503333
# 227843  149780  Grp445  0.433333  1.013333  1.163333  0.940000  0.930000
# 227844   22175  Grp143  1.006667  0.553333  0.946667  1.206667  0.406667
#
#             Per6      Per7      Per8  ...     Cred4     Cred5     Cred6  \
# 227840  1.846667  0.600000  1.103333  ...  0.533333  0.680000  0.693333
# 227841  0.466667  0.733333  0.590000  ...  0.730000  0.646667  0.656667
# 227842  0.396667  0.683333  0.620000  ...  0.696667  0.663333  0.673333
# 227843  0.900000  0.813333  0.720000  ...  0.540000  0.766667  0.710000
# 227844  0.750000  0.520000  0.756667  ...  0.580000  0.683333  0.676667
#
#         Normalised_FNT  Target   data  geo_score  instance_scores  \
# 227840       -246.5025     0.0  train      -0.14            -0.44
# 227841       -249.7775     0.0  train       0.39            -0.40
# 227842       -249.7775     0.0  train       1.03            -0.13
# 227843       -242.7500     0.0  train      -3.29            -0.66
# 227844       -235.0000     0.0  train      -0.36            -0.22
#
#         qsets_normalized_tat  lambda_wt
# 227840                 -0.55       0.75
# 227841                  0.38      -0.98
# 227842                  0.01       0.15
# 227843                  0.38       1.53
# 227844                  0.55       0.00
#
# [5 rows x 33 columns]

# %%
test.head()
# Out:
#             id   Group      Per1      Per2      Per3      Per4      Per5  \
# 227845  146574  Grp229 -0.300000  1.540000  0.220000 -0.280000  0.570000
# 227846  268759  Grp141  0.633333  0.953333  0.810000  0.466667  0.910000
# 227847   59727  Grp188  1.043333  0.740000  0.860000  1.006667  0.583333
# 227848  151544  Grp426  1.283333  0.300000  0.576667  0.636667  0.256667
# 227849  155008  Grp443  1.186667  0.326667  0.476667  0.866667  0.436667
#
#             Per6      Per7      Per8  ...     Cred4     Cred5     Cred6  \
# 227845  0.260000  0.700000  1.076667  ...  0.796667  0.823333  0.783333
# 227846  0.253333  1.040000  0.550000  ...  0.630000  0.673333  0.673333
# 227847  0.616667  0.630000  0.686667  ...  0.596667  0.680000  0.670000
# 227848  0.543333  0.356667  0.663333  ...  0.320000  0.676667  0.660000
# 227849  0.680000  0.476667  0.686667  ...  0.546667  0.650000  0.663333
#
#         Normalised_FNT  Target  data  geo_score  instance_scores  \
# 227845       -249.7500     NaN  test       0.25            -0.04
# 227846       -249.8125     NaN  test       0.43            -0.77
# 227847       -248.1200     NaN  test       1.32             0.11
# 227848       -222.9875     NaN  test      -2.11             0.33
# 227849       -196.2200     NaN  test      -2.11            -0.37
#
#         qsets_normalized_tat  lambda_wt
# 227845                 -0.43       0.76
# 227846                 -0.62       0.18
# 227847                 -0.41       0.39
# 227848                  0.37       1.80
# 227849                 -0.13       1.89
#
# [5 rows x 33 columns]

# %%
train.shape
# Out:
# (227845, 33)

# %%
train.isnull().sum()
# Out:
# id                      0
# Group                   0
# Per1                    0
# Per2                    0
# Per3                    0
# Per4                    0
# Per5                    0
# Per6                    0
# Per7                    0
# Per8                    0
# Per9                    0
# Dem1                    0
# Dem2                    0
# Dem3                    0
# Dem4                    0
# Dem5                    0
# Dem6                    0
# Dem7                    0
# Dem8                    0
# Dem9                    0
# Cred1                   0
# Cred2                   0
# Cred3                   0
# Cred4                   0
# Cred5                   0
# Cred6                   0
# Normalised_FNT          0
# Target                  0
# data                    0
# geo_score               0
# instance_scores         0
# qsets_normalized_tat    0
# lambda_wt               0
# dtype: int64

# %%
test.shape
# Out:
# (56962, 33)

# %%
test.isnull().sum()
# Out:
# id                          0
# Group                       0
# Per1                        0
# Per2                        0
# Per3                        0
# Per4                        0
# Per5                        0
# Per6                        0
# Per7                        0
# Per8                        0
# Per9                        0
# Dem1                        0
# Dem2                        0
# Dem3                        0
# Dem4                        0
# Dem5                        0
# Dem6                        0
# Dem7                        0
# Dem8                        0
# Dem9                        0
# Cred1                       0
# Cred2                       0
# Cred3                       0
# Cred4                       0
# Cred5                       0
# Cred6                       0
# Normalised_FNT              0
# Target                  56962
# data                        0
# geo_score                   0
# instance_scores             0
# qsets_normalized_tat        0
# lambda_wt                   0
# dtype: int64

# %%
train.columns
# Out:
# Index(['id', 'Group', 'Per1', 'Per2', 'Per3', 'Per4', 'Per5', 'Per6', 'Per7',
#        'Per8', 'Per9', 'Dem1', 'Dem2', 'Dem3', 'Dem4', 'Dem5', 'Dem6', 'Dem7',
#        'Dem8', 'Dem9', 'Cred1', 'Cred2', 'Cred3', 'Cred4', 'Cred5', 'Cred6',
#        'Normalised_FNT', 'Target', 'data', 'geo_score', 'instance_scores',
#        'qsets_normalized_tat', 'lambda_wt'],
#       dtype='object')

# %%
# Split the data into independent and dependent variable
x_train = train.drop(['id','Group','Target', 'data'], axis=1)
y_train = train['Target']

# %%
test.columns
# Out:
# Index(['id', 'Group', 'Per1', 'Per2', 'Per3', 'Per4', 'Per5', 'Per6', 'Per7',
#        'Per8', 'Per9', 'Dem1', 'Dem2', 'Dem3', 'Dem4', 'Dem5', 'Dem6', 'Dem7',
#        'Dem8', 'Dem9', 'Cred1', 'Cred2', 'Cred3', 'Cred4', 'Cred5', 'Cred6',
#        'Normalised_FNT', 'Target', 'data', 'geo_score', 'instance_scores',
#        'qsets_normalized_tat', 'lambda_wt'],
#       dtype='object')

# %%
x_test = test.drop(['id','Group','Target','data'], axis=1)
y_test = test['Target']

# %%
x_test.head()
# Out:
#             Per1      Per2      Per3      Per4      Per5      Per6      Per7  \
# 227845 -0.300000  1.540000  0.220000 -0.280000  0.570000  0.260000  0.700000
# 227846  0.633333  0.953333  0.810000  0.466667  0.910000  0.253333  1.040000
# 227847  1.043333  0.740000  0.860000  1.006667  0.583333  0.616667  0.630000
# 227848  1.283333  0.300000  0.576667  0.636667  0.256667  0.543333  0.356667
# 227849  1.186667  0.326667  0.476667  0.866667  0.436667  0.680000  0.476667
#
#             Per8      Per9      Dem1  ...     Cred2     Cred3     Cred4  \
# 227845  1.076667  0.930000  0.156667  ...  0.813333  0.776667  0.796667
# 227846  0.550000  0.543333  0.433333  ...  0.703333  0.806667  0.630000
# 227847  0.686667  0.593333  1.250000  ...  0.753333  0.870000  0.596667
# 227848  0.663333  1.156667  1.186667  ...  0.606667  0.456667  0.320000
# 227849  0.686667  1.476667  1.213333  ...  0.896667  0.566667  0.546667
#
#            Cred5     Cred6  Normalised_FNT  geo_score  instance_scores  \
# 227845  0.823333  0.783333       -249.7500       0.25            -0.04
# 227846  0.673333  0.673333       -249.8125       0.43            -0.77
# 227847  0.680000  0.670000       -248.1200       1.32             0.11
# 227848  0.676667  0.660000       -222.9875      -2.11             0.33
# 227849  0.650000  0.663333       -196.2200      -2.11            -0.37
#
#         qsets_normalized_tat  lambda_wt
# 227845                 -0.43       0.76
# 227846                 -0.62       0.18
# 227847                 -0.41       0.39
# 227848                  0.37       1.80
# 227849                 -0.13       1.89
#
# [5 rows x 29 columns]

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227845 entries, 0 to 227844
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Per1                  227845 non-null  float64
#  1   Per2                  227845 non-null  float64
#  2   Per3                  227845 non-null  float64
#  3   Per4                  227845 non-null  float64
#  4   Per5                  227845 non-null  float64
#  5   Per6                  227845 non-null  float64
#  6   Per7                  227845 non-null  float64
#  7   Per8                  227845 non-null  float64
#  8   Per9                  227845 non-null  float64
#  9   Dem1                  227845 non-null  float64
#  10  Dem2                  227845 non-null  float64
#  11  Dem3                  227845 non-null  float64
#  12  Dem4                  227845 non-null  float64
#  13  Dem5                  227845 non-null  float64
#  14  Dem6                  227845 non-null  float64
#  15  Dem7                  227845 non-null  float64
#  16  Dem8                  227845 non-null  float64
#  17  Dem9                  227845 non-null  float64
#  18  Cred1                 227845 non-null  float64
#  19  Cred2                 227845 non-null  float64
#  20  Cred3                 227845 non-null  float64
#  21  Cred4                 227845 non-null  float64
#  22  Cred5                 227845 non-null  float64
#  23  Cred6                 227845 non-null  float64
#  24  Normalised_FNT        227845 non-null  float64
#  25  geo_score             227845 non-null  float64
#  26  instance_scores       227845 non-null  float64
#  27  qsets_normalized_tat  227845 non-null  float64
#  28  lambda_wt             227845 non-null  float64
# dtypes: float64(29)
# memory usage: 52.1 MB

# %%
def boxplots(col):
    sns.boxplot(x_train[col])
    plt.show()
    
for i in list(x_train.select_dtypes(exclude=['object']).columns[1:]):
    boxplots(i)

# %%
x_train.describe()
# Out:
#                 Per1           Per2           Per3           Per4  \
# count  227845.000000  227845.000000  227845.000000  227845.000000
# mean        0.666006       0.667701       0.666315       0.666687
# std         0.654133       0.548305       0.506357       0.471956
# min       -18.136667     -23.573333     -15.443333      -1.226667
# 25%         0.360000       0.470000       0.370000       0.383333
# 50%         0.670000       0.690000       0.726667       0.660000
# 75%         1.103333       0.933333       1.010000       0.913333
# max         1.483333       8.020000       3.793333       6.163333
#
#                 Per5           Per6           Per7           Per8  \
# count  227845.000000  227845.000000  227845.000000  227845.000000
# mean        0.666723       0.667378       0.666934       0.666279
# std         0.461393       0.444573       0.415657       0.401546
# min       -37.246667      -8.053333     -13.853333     -23.740000
# 25%         0.436667       0.410000       0.483333       0.596667
# 50%         0.650000       0.576667       0.680000       0.673333
# 75%         0.870000       0.800000       0.856667       0.776667
# max        12.266667      25.100000      40.863333       7.336667
#
#                 Per9           Dem1  ...          Cred2          Cred3  \
# count  227845.000000  227845.000000  ...  227845.000000  227845.000000
# mean        0.666688       0.666576  ...       0.666264       0.666755
# std         0.366537       0.340436  ...       0.202204       0.174204
# min        -3.810000      -0.893333  ...      -0.280000      -2.766667
# 25%         0.453333       0.413333  ...       0.546667       0.560000
# 50%         0.650000       0.656667  ...       0.680000       0.673333
# 75%         0.866667       0.913333  ...       0.813333       0.783333
# max         5.863333       4.673333  ...       2.193333       3.173333
#
#                Cred4          Cred5          Cred6  Normalised_FNT  \
# count  227845.000000  227845.000000  227845.000000   227845.000000
# mean        0.666878       0.666566       0.666776     -227.954170
# std         0.160803       0.135762       0.111612       61.951661
# min        -0.080000      -6.856667      -4.476667     -250.000000
# 25%         0.556667       0.643333       0.650000     -248.617500
# 50%         0.650000       0.666667       0.670000     -244.510000
# 75%         0.746667       0.696667       0.693333     -230.750000
# max         1.840000      11.203333      11.950000     6172.790000
#
#            geo_score  instance_scores  qsets_normalized_tat      lambda_wt
# count  227845.000000    227845.000000         227845.000000  227845.000000
# mean       -0.000135        -0.000123             -0.000103       0.000350
# std         0.997518         1.091488              0.850163       0.957957
# min       -18.680000       -24.590000            -25.160000     -19.210000
# 25%        -0.410000        -0.540000             -0.480000      -0.430000
# 50%         0.140000        -0.090000             -0.070000       0.050000
# 75%         0.620000         0.450000              0.400000       0.490000
# max         7.850000        23.750000              8.540000      10.530000
#
# [8 rows x 29 columns]

# %%
x_train.head()
# Out:
#        Per1      Per2      Per3      Per4      Per5      Per6      Per7  \
# 0  1.070000  0.580000  0.480000  0.766667  1.233333  1.993333  0.340000
# 1  0.473333  1.206667  0.883333  1.430000  0.726667  0.626667  0.810000
# 2  1.130000  0.143333  0.946667  0.123333  0.080000  0.836667  0.056667
# 3  0.636667  1.090000  0.750000  0.940000  0.743333  0.346667  0.956667
# 4  0.560000  1.013333  0.593333  0.416667  0.773333  0.460000  0.853333
#
#        Per8      Per9      Dem1  ...     Cred2     Cred3     Cred4     Cred5  \
# 0  1.010000  0.863333  0.460000  ...  1.010000  0.933333  0.603333  0.686667
# 1  0.783333  0.190000  0.470000  ...  0.690000  0.560000  0.670000  0.553333
# 2  0.756667  0.226667  0.660000  ...  0.383333  0.763333  0.670000  0.686667
# 3  0.633333  0.486667  1.096667  ...  0.846667  0.423333  0.520000  0.846667
# 4  0.796667  0.516667  0.756667  ...  0.526667  0.520000  0.716667  0.706667
#
#       Cred6  Normalised_FNT  geo_score  instance_scores  qsets_normalized_tat  \
# 0  0.673333       -245.7500       0.22            -0.06                 -0.70
# 1  0.653333       -248.0000      -0.25             0.52                  0.14
# 2  0.673333       -233.1250      -0.95             1.56                 -0.43
# 3  0.760000       -249.7775       0.49             0.70                 -0.31
# 4  0.673333       -247.5775       0.85            -0.47                 -0.63
#
#    lambda_wt
# 0      -0.13
# 1       0.66
# 2      -0.51
# 3       0.72
# 4       0.60
#
# [5 rows x 29 columns]

# %%
y_train.value_counts()
# Out:
# 0.0    227451
# 1.0       394
# Name: Target, dtype: int64

# %%
outlier_factor = 394/(394+227457)
outlier_factor
# Out:
# 0.0017292002229527192

# %%
# handling imbalance dataset
import imblearn

# %%
from imblearn.over_sampling import RandomOverSampler
over = RandomOverSampler()
x_train_over, y_train_over = over.fit_resample(x_train, y_train)

# %%
print(y_train_over.value_counts())
# Out:
# 0.0    227451
# 1.0    227451
# Name: Target, dtype: int64

# %%
227451+227451
# Out:
# 454902

# %%
# Undersampling method - pls don't use it. this is just for reference
from imblearn.under_sampling import RandomUnderSampler
under = RandomUnderSampler()
x_train_under, y_train_under = under.fit_resample(x_train, y_train)

# %%
y_train_under.value_counts()
# Out:
# 0.0    394
# 1.0    394
# Name: Target, dtype: int64

# %%
394+394
# Out:
# 788

# %%
x_train_over.columns
# Out:
# Index(['Per1', 'Per2', 'Per3', 'Per4', 'Per5', 'Per6', 'Per7', 'Per8', 'Per9',
#        'Dem1', 'Dem2', 'Dem3', 'Dem4', 'Dem5', 'Dem6', 'Dem7', 'Dem8', 'Dem9',
#        'Cred1', 'Cred2', 'Cred3', 'Cred4', 'Cred5', 'Cred6', 'Normalised_FNT',
#        'geo_score', 'instance_scores', 'qsets_normalized_tat', 'lambda_wt'],
#       dtype='object')

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaler = scaler.fit_transform(x_train_over)
x_test_scaler = scaler.fit_transform(x_test)

# %%
x_train_scaler = pd.DataFrame(x_train_scaler, columns=x_train_over.columns)

# %%
x_train_scaler.head(1)
# Out:
#        Per1      Per2     Per3      Per4      Per5      Per6      Per7  \
# 0  0.631585 -0.548775  0.46779 -0.617545  0.760108  2.718394  0.302195
#
#        Per8     Per9      Dem1  ...     Cred2     Cred3    Cred4     Cred5  \
# 0  0.133943  0.80484 -0.904943  ...  1.920363  1.136021 -0.43943  0.003899
#
#       Cred6  Normalised_FNT  geo_score  instance_scores  qsets_normalized_tat  \
# 0 -0.054691       -0.341518   0.731877         0.602367              0.437226
#
#    lambda_wt
# 0   0.708953
#
# [1 rows x 29 columns]

# %%
x_test.columns
# Out:
# Index(['Per1', 'Per2', 'Per3', 'Per4', 'Per5', 'Per6', 'Per7', 'Per8', 'Per9',
#        'Dem1', 'Dem2', 'Dem3', 'Dem4', 'Dem5', 'Dem6', 'Dem7', 'Dem8', 'Dem9',
#        'Cred1', 'Cred2', 'Cred3', 'Cred4', 'Cred5', 'Cred6', 'Normalised_FNT',
#        'geo_score', 'instance_scores', 'qsets_normalized_tat', 'lambda_wt'],
#       dtype='object')

# %%
x_test_scaler = pd.DataFrame(x_test_scaler, columns=x_test.columns)

# %%
x_test_scaler.head()
# Out:
#        Per1      Per2      Per3      Per4      Per5      Per6      Per7  \
# 0 -1.496031  1.570058 -0.893190 -2.005630 -0.212044 -0.913347  0.086224
# 1 -0.055545  0.520338  0.282944 -0.423586  0.535501 -0.928426  0.938507
# 2  0.577239  0.138622  0.382617  0.720570 -0.182729 -0.106653 -0.089246
# 3  0.947650 -0.648668 -0.182194 -0.063389 -0.900958 -0.272515 -0.774414
# 4  0.798457 -0.600954 -0.381539  0.423937 -0.505199  0.036592 -0.473608
#
#        Per8      Per9      Dem1  ...     Cred2     Cred3     Cred4     Cred5  \
# 0  1.063427  0.721904 -1.503455  ...  0.723101  0.641604  0.815166  1.205872
# 1 -0.307743 -0.337788 -0.688414  ...  0.174728  0.816024 -0.223190  0.048338
# 2  0.048067 -0.200758  1.717428  ...  0.423989  1.184244 -0.430861  0.099784
# 3 -0.012681  1.343103  1.530852  ... -0.307175 -1.218874 -2.154532  0.074061
# 4  0.048067  2.220090  1.609411  ...  1.138536 -0.579335 -0.742368 -0.131723
#
#       Cred6  Normalised_FNT  geo_score  instance_scores  qsets_normalized_tat  \
# 0  1.131651       -0.339607   0.248033        -0.037541             -0.508807
# 1  0.068690       -0.340572   0.426973        -0.714570             -0.733387
# 2  0.036479       -0.314450   1.311732         0.101575             -0.485167
# 3 -0.060154        0.073448  -2.098070         0.305611              0.436797
# 4 -0.027943        0.486580  -2.098070        -0.343595             -0.154205
#
#    lambda_wt
# 0   0.792116
# 1   0.188701
# 2   0.407179
# 3   1.874103
# 4   1.967736
#
# [5 rows x 29 columns]

# %%
# pre-processing part completed

# %%
sns.heatmap(all_data.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
def distplot(col):
    sns.distplot(x_train[col])
    plt.show()
    
for i in list(x_train.columns)[1:]:
    distplot(i)

# %%
# Please use advanced EDA part - 
# pandas profiling or dataprep or dtale package

# %% [markdown]
# # Model Buidling

# %%
# Deep Learning 
# Isolation Forest, Local Outlier Factor and OneSample SVM
# Voting and Stacking 
# grid search cv and randomised search cv

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_train_over, y_train_over, 
                                                    test_size=0.3,random_state=101)

# %% [markdown]
# # Building Machine Learning Model along with Hyperparameter

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
GridSearchCV()

# %%
param = {'n_estimators' : [50,70,80,90,100], 'criterion' : ['gini', 'entropy'],
        'max_depth' : [1,2,3,4,5], 'min_samples_split' :[2,3,5,6,7], 
         'min_samples_leaf' :[1,2,3,4,5],
    'min_weight_fraction_leaf': [0.0,0.1,0.5,0.9,1.0], 
    'max_features' : ["auto", "sqrt", "log2"] , 'max_leaf_nodes' : [0,1,2,3,4],
    'min_impurity_decrease' : [0.0,0.1,0.2,0.5,0.9], 'bootstrap' : [True, False],
    'oob_score' : [False,True], 'max_samples' : [1,5,10,6,8]}

# %%
random_forest_hyper = RandomizedSearchCV(RandomForestClassifier(),param, n_iter=10, cv=10)

# %%
random_forest_hyper
# Out:
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(),
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [1, 2, 3, 4, 5],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'max_leaf_nodes': [0, 1, 2, 3, 4],
#                                         'max_samples': [1, 5, 10, 6, 8],
#                                         'min_impurity_decrease': [0.0, 0.1, 0.2,
#                                                                   0.5, 0.9],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5],
#                                         'min_samples_split': [2, 3, 5, 6, 7],
#                                         'min_weight_fraction_leaf': [0.0, 0.1,
#                                                                      0.5, 0.9,
#                                                                      1.0],
#                                         'n_estimators': [50, 70, 80, 90, 100],
#                                         'oob_score': [False, True]})

# %%
random_forest_hyper.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(),
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [1, 2, 3, 4, 5],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'max_leaf_nodes': [0, 1, 2, 3, 4],
#                                         'max_samples': [1, 5, 10, 6, 8],
#                                         'min_impurity_decrease': [0.0, 0.1, 0.2,
#                                                                   0.5, 0.9],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5],
#                                         'min_samples_split': [2, 3, 5, 6, 7],
#                                         'min_weight_fraction_leaf': [0.0, 0.1,
#                                                                      0.5, 0.9,
#                                                                      1.0],
#                                         'n_estimators': [50, 70, 80, 90, 100],
#                                         'oob_score': [False, True]})

# %%
random_forest_hyper.best_params_
# Out:
# {'oob_score': False,
#  'n_estimators': 80,
#  'min_weight_fraction_leaf': 0.1,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'min_impurity_decrease': 0.2,
#  'max_samples': 6,
#  'max_leaf_nodes': 3,
#  'max_features': 'sqrt',
#  'max_depth': 2,
#  'criterion': 'entropy',
#  'bootstrap': True}

# %%
random_forest_hyper.best_score_
# Out:
# 0.9018185917717145

# %%
final_RF_model = RandomForestClassifier(n_estimators = 80, criterion='entropy', max_depth=2, min_samples_split=2, min_samples_leaf=2,
    min_weight_fraction_leaf=0.1, max_features='sqrt', max_leaf_nodes=3,
    min_impurity_decrease=0.2, bootstrap=True, oob_score=False, n_jobs=None,random_state=None,
    verbose=0, warm_start=False, class_weight=None,ccp_alpha=0.0,max_samples=6)

# %%
final_RF_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=2, max_features='sqrt',
#                        max_leaf_nodes=3, max_samples=6,
#                        min_impurity_decrease=0.2, min_samples_leaf=2,
#                        min_weight_fraction_leaf=0.1, n_estimators=80)

# %%
y_pred_train = final_RF_model.predict(x_train)
y_pred_test = final_RF_model.predict(x_test)

# %%
# Evaluation
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[68160    38]
#  [14010 54263]]

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91     68198
#          1.0       1.00      0.79      0.89     68273
#
#     accuracy                           0.90    136471
#    macro avg       0.91      0.90      0.90    136471
# weighted avg       0.91      0.90      0.90    136471

# %%
print("Train Accuracy", accuracy_score(y_train, y_pred_train))
print("****************"*10)
print("Test Accuracy", accuracy_score(y_test, y_pred_test))
# Out:
# Train Accuracy 0.8964987705342758
# ****************************************************************************************************************************************************************
# Test Accuracy 0.8970623795531651

# %% [markdown]
# # Deep Neural Network

# %%
import tensorflow as tf
from tensorflow import keras
tf.__version__
# Out:
# '2.11.0'

# %%
dnn = tf.keras.models.Sequential()
dnn.add(tf.keras.layers.Dense(units=6, activation='relu'))
dnn.add(tf.keras.layers.Dense(units=6, activation='relu'))
dnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
dnn.compile(optimizer = 'adam', loss='binary_crossentropy', metrics=['accuracy'])
dnn.fit(x_train, y_train, batch_size=50, epochs=50)
# Out:
# Epoch 1/50
# 6369/6369 [==============================] - 32s 4ms/step - loss: 0.1821 - accuracy: 0.9317
# Epoch 2/50
# 6369/6369 [==============================] - 28s 4ms/step - loss: 0.1462 - accuracy: 0.9426
# Epoch 3/50
# 6369/6369 [==============================] - 24s 4ms/step - loss: 0.1331 - accuracy: 0.9462
# Epoch 4/50
# 6369/6369 [==============================] - 23s 4ms/step - loss: 0.1235 - accuracy: 0.9468
# Epoch 5/50
# 6369/6369 [==============================] - 27s 4ms/step - loss: 0.1191 - accuracy: 0.9472
# Epoch 6/50
# 6369/6369 [==============================] - 25s 4ms/step - loss: 0.1143 - accuracy: 0.9476
# Epoch 7/50
# 6369/6369 [==============================] - 26s 4ms/step - loss: 0.1112 - accuracy: 0.9488
# Epoch 8/50
# 6369/6369 [==============================] - 24s 4ms/step - loss: 0.1050 - accuracy: 0.9522
# Epoch 9/50
# 6369/6369 [==============================] - 26s 4ms/step - loss: 0.1003 - accuracy: 0.9543
# Epoch 10/50
# 6369/6369 [==============================] - 26s 4ms/step - loss: 0.0971 - accuracy: 0.9557
# Epoch 11/50
# 6369/6369 [==============================] - 30s 5ms/step - loss: 0.0937 - accuracy: 0.9573
# Epoch 12/50
# 6369/6369 [==============================] - 26s 4ms/step - loss: 0.0908 - accuracy: 0.9584
# Epoch 13/50
# 6369/6369 [==============================] - 25s 4ms/step - loss: 0.0885 - accuracy: 0.9592
# Epoch 14/50
# 6369/6369 [==============================] - 25s 4ms/step - loss: 0.0886 - accuracy: 0.9588
# Epoch 15/50
# 6369/6369 [==============================] - 25s 4ms/step - loss: 0.0870 - accuracy: 0.9592
# Epoch 16/50
# 6369/6369 [==============================] - 27s 4ms/step - loss: 0.0859 - accuracy: 0.9598
# Epoch 17/50
# 6369/6369 [==============================] - 28s 4ms/step - loss: 0.0861 - accuracy: 0.9594
# Epoch 18/50
# 6369/6369 [==============================] - 25s 4ms/step - loss: 0.0852 - accuracy: 0.9595
# Epoch 19/50
# 6369/6369 [==============================] - 33s 5ms/step - loss: 0.0845 - accuracy: 0.9598
# Epoch 20/50
# 2343/6369 [==========>...................] - ETA: 18s - loss: 0.0834 - accuracy: 0.9607

# %%
dnn.fit(x_test, y_test, batch_size=50, epochs=50)
